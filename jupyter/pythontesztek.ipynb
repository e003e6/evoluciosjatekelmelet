# %%
# fájlok importálása a root/python mappából
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent / 'python'))

from szim_v2 import Szimulacio as Szmode1
from szim_mode2 import Szimulacio as Szmode2

# %%
# társadalmi norma mindkét modellhez
tn = ['G', 'B',
      'B', 'G',
      'B', 'B']

# %% [markdown]
# ---
#
# ### Modell 1
# Opcionális paraméterek és alapértelmezett értékek:
# ```python
# n=100, generations=1000, rounds=10, fr=(0.8, 'CD'), init_good=0.5,
# mu=0.02, epsilon=0.01, e_rep=0, e_act=0, c=3, b=9, alpha=1, beta=4
# ```

# %%
sz = Szmode1(tn)

# %%
sz.run()
# Out:
# Szimuláció: 100.0%

# %%
sz.plot(rangee=(2, 3))

# %% [markdown]
# ---
#
# ### Modell 2
#
# Opcionális paraméterek és alapértelmezett értékek:
# ```python
# n=100, generations=1000, rounds=10, fr=(0.8, 'CD'), init_good=0.5,
# mu=0.02, epsilon=0.01, e_rep=0, e_act=0, c=3, b=9, alpha=1, beta=4,
# communication=100, com_mode=1, init_correlation=0
# ```

# %%
sz2 = Szmode2(tn)

# %%
sz2.run()
# Out:
# Szimuláció: 100.0%

# %%
sz2.plot((-1, 2))
